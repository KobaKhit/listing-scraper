# %%
import requests
from requests.adapters import HTTPAdapter, Retry

from tqdm import tqdm
import math
import itertools
import json
import time
import os


def get_events(league = 'NBA', start = "2022-09-09", end = "9999-12-31"):
    '''
    Get all league events on stubhub.
    '''

    event_category = {'NBA':{'path':'nba-tickets','categoryid': "6453"},
                      'NFL':{'path':'nfl-tickets','categoryid': "5084"}}


    url = f"https://www.stubhub.com/{event_category[league]['path']}"

    querystring = {"pageIndex":"0",
                "gridFilterType":"0",
                "sortBy":"0",
                "method":"GetFilteredEvents",
                "categoryId": event_category[league]['categoryid'],
                "from": start,
                "to": end}

    response = requests.request("POST", url, params=querystring).json()

    total_pages = math.ceil((response['totalCount'] - 2*response['pageSize'])/response['pageSize'])
    items = response['items']
    for i in items:
        i['eventid_from_url'] = int(i['url'].strip('/').split('/')[-1])
    item_dicts = []
    with tqdm(total=total_pages) as pbar:
        while response['remaining'] > 0:
            item_dicts.append(items)

            querystring['pageIndex'] = int(querystring['pageIndex']) + 1
            response = requests.request("POST", url, params=querystring).json()
            items = response['items']
            for i in items:
                i['eventid_from_url'] = int(i['url'].strip('/').split('/')[-1])
            pbar.update(1)
            
        # append last page
        item_dicts.append(items)

    return list(itertools.chain.from_iterable(item_dicts))

# %%
evs = get_events('NFL')
# Out:
# 8it [00:02,  3.38it/s]

# %%
evs[0]
# Out:
# {'eventId': 150021223,
#  'name': 'Philadelphia Eagles at Houston Texans',
#  'url': '/houston-texans-houston-tickets-11-3-2022/event/105255775/',
#  'dayOfWeek': 'Thu',
#  'formattedDate': 'Nov 03',
#  'formattedTime': '7:15 PM',
#  'formattedDateWithoutYear': 'Nov 03',
#  'isTbd': False,
#  'isDateConfirmed': True,
#  'isTimeConfirmed': True,
#  'venueName': 'NRG Stadium',
#  'formattedVenueLocation': 'Houston, TX, USA',
#  'countryCode': 'US',
#  'formattedMinPrice': '$40',
#  'userDistanceFromVenue': 2166435.96663194,
#  'formattedDistanceInMiles': '',
#  'formattedRescheduledFromDate': '',
#  'eventCountdownMessage': 'Tomorrow',
#  'timeToEventTotalMilliseconds': 0,
#  'hasActiveListings': True,
#  'eventid_from_url': 105255775}

# %%
event_path = '/detroit-lions-detroit-tickets-9-18-2022/event/105255466/'
url = f"https://www.stubhub.com/event/105255466"
response = requests.request("POST", url)
response = requests.request("POST", response.url)
response
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:670, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669 # Make the request on the httplib connection object.
# --> 670 httplib_response = self._make_request(
#     671     conn,
#     672     method,
#     673     url,
#     674     timeout=timeout_obj,
#     675     body=body,
#     676     headers=headers,
#     677     chunked=chunked,
#     678 )
#     680 # If we're going to release the connection in ``finally:``, then
#     681 # the response doesn't need to know about the connection. Otherwise
#     682 # it will also try to release it and we'll have a double-release
#     683 # mess.
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:381, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 try:
# --> 381     self._validate_conn(conn)
#     382 except (SocketTimeout, BaseSSLError) as e:
#     383     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:978, in HTTPSConnectionPool._validate_conn(self, conn)
#     977 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978     conn.connect()
#     980 if not conn.is_verified:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connection.py:362, in HTTPSConnection.connect(self)
#     360     context.load_default_certs()
# --> 362 self.sock = ssl_wrap_socket(
#     363     sock=conn,
#     364     keyfile=self.key_file,
#     365     certfile=self.cert_file,
#     366     key_password=self.key_password,
#     367     ca_certs=self.ca_certs,
#     368     ca_cert_dir=self.ca_cert_dir,
#     369     ca_cert_data=self.ca_cert_data,
#     370     server_hostname=server_hostname,
#     371     ssl_context=context,
#     372 )
#     374 if self.assert_fingerprint:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/util/ssl_.py:386, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385 if HAS_SNI and server_hostname is not None:
# --> 386     return context.wrap_socket(sock, server_hostname=server_hostname)
#     388 warnings.warn(
#     389     "An HTTPS request has been made, but the SNI (Server Name "
#     390     "Indication) extension to TLS is not available on this platform. "
#    (...)
#     396     SNIMissingWarning,
#     397 )
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:726, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     724     e = ProtocolError("Connection aborted.", e)
# --> 726 retries = retries.increment(
#     727     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728 )
#     729 retries.sleep()
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/util/retry.py:446, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     445 if new_retry.is_exhausted():
# --> 446     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     448 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.stubhub.com', port=443): Max retries exceeded with url: /event/105255466 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> event_path = '/detroit-lions-detroit-tickets-9-18-2022/event/105255466/'
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> url = f"https://www.stubhub.com/event/105255466"
# ----> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> response = requests.request("POST", url)
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> response = requests.request("POST", response.url)
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> response
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     559         raise ProxyError(e, request=request)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
# --> 563         raise SSLError(e, request=request)
#     565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='www.stubhub.com', port=443): Max retries exceeded with url: /event/105255466 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
class EnhancedSession(requests.Session):
    '''
    Set timeout at the session level .
    '''
    def __init__(self, timeout=(3.05, 4)):
        self.timeout = timeout
        return super().__init__()

    def request(self, method, url, **kwargs):
        # print("EnhancedSession request")
        if "timeout" not in kwargs:
            kwargs["timeout"] = self.timeout
        return super().request(method, url, **kwargs)

def prepare_session():
    '''
    Prepare requests session with default timeout and retry.
    '''
    s = EnhancedSession(timeout=10)
    retries = Retry(total=5,
                    backoff_factor=0.1,
                    method_whitelist=["POST", "GET"])
    s.mount('http://', HTTPAdapter(max_retries=retries))
    s.mount('https://', HTTPAdapter(max_retries=retries))
    return s

def get_listings(eventid):
    '''
    Get all event listings.
    '''
    s = prepare_session()
    
    url = f"https://www.stubhub.com/event/{eventid}"
    url = s.request("POST", url,allow_redirects=True).url
    response = s.request("POST", url)


    if response.status_code == 404:
        print('404, Probably, no listings for event {}'.format(eventid))
        print(url)
        return None

    respjson= response.json()
    querystring = {"CurrentPage":"1"}
    total_pages = math.ceil((respjson['TotalCount'] - 2*respjson['PageSize'])/respjson['PageSize'])
    items = respjson['Items']
    item_dicts = []
    with tqdm(total=total_pages, desc=f'Event Id: {eventid}', leave=False) as pbar:
        while respjson['ItemsRemaining'] > 0:
            item_dicts.append(items)

            querystring['CurrentPage'] = int(querystring['CurrentPage']) + 1
            respjson = s.request("POST", url, params=querystring).json()
            items = respjson['Items']
            pbar.set_description(f'Code: {response.status_code} Event Id: {eventid}')
            pbar.update(1)
            
        # append last page
        item_dicts.append(items)

    return list(itertools.chain.from_iterable(item_dicts))

def parse_listing(l):
    '''
    Parse listing by extracting relevant columns.
    '''
    listing = {}
    for c in columns:
        listing[c] = columns[c]

# %%
listings = get_listings(150021320)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:670, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669 # Make the request on the httplib connection object.
# --> 670 httplib_response = self._make_request(
#     671     conn,
#     672     method,
#     673     url,
#     674     timeout=timeout_obj,
#     675     body=body,
#     676     headers=headers,
#     677     chunked=chunked,
#     678 )
#     680 # If we're going to release the connection in ``finally:``, then
#     681 # the response doesn't need to know about the connection. Otherwise
#     682 # it will also try to release it and we'll have a double-release
#     683 # mess.
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:381, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 try:
# --> 381     self._validate_conn(conn)
#     382 except (SocketTimeout, BaseSSLError) as e:
#     383     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:978, in HTTPSConnectionPool._validate_conn(self, conn)
#     977 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978     conn.connect()
#     980 if not conn.is_verified:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connection.py:362, in HTTPSConnection.connect(self)
#     360     context.load_default_certs()
# --> 362 self.sock = ssl_wrap_socket(
#     363     sock=conn,
#     364     keyfile=self.key_file,
#     365     certfile=self.cert_file,
#     366     key_password=self.key_password,
#     367     ca_certs=self.ca_certs,
#     368     ca_cert_dir=self.ca_cert_dir,
#     369     ca_cert_data=self.ca_cert_data,
#     370     server_hostname=server_hostname,
#     371     ssl_context=context,
#     372 )
#     374 if self.assert_fingerprint:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/util/ssl_.py:386, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385 if HAS_SNI and server_hostname is not None:
# --> 386     return context.wrap_socket(sock, server_hostname=server_hostname)
#     388 warnings.warn(
#     389     "An HTTPS request has been made, but the SNI (Server Name "
#     390     "Indication) extension to TLS is not available on this platform. "
#    (...)
#     396     SNIMissingWarning,
#     397 )
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:754, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     751     log.warning(
#     752         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     753     )
# --> 754     return self.urlopen(
#     755         method,
#     756         url,
#     757         body,
#     758         headers,
#     759         retries,
#     760         redirect,
#     761         assert_same_host,
#     762         timeout=timeout,
#     763         pool_timeout=pool_timeout,
#     764         release_conn=release_conn,
#     765         chunked=chunked,
#     766         body_pos=body_pos,
#     767         **response_kw
#     768     )
#     770 # Handle redirect?
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:754, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     751     log.warning(
#     752         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     753     )
# --> 754     return self.urlopen(
#     755         method,
#     756         url,
#     757         body,
#     758         headers,
#     759         retries,
#     760         redirect,
#     761         assert_same_host,
#     762         timeout=timeout,
#     763         pool_timeout=pool_timeout,
#     764         release_conn=release_conn,
#     765         chunked=chunked,
#     766         body_pos=body_pos,
#     767         **response_kw
#     768     )
#     770 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 754 (2 times)]
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:754, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     751     log.warning(
#     752         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     753     )
# --> 754     return self.urlopen(
#     755         method,
#     756         url,
#     757         body,
#     758         headers,
#     759         retries,
#     760         redirect,
#     761         assert_same_host,
#     762         timeout=timeout,
#     763         pool_timeout=pool_timeout,
#     764         release_conn=release_conn,
#     765         chunked=chunked,
#     766         body_pos=body_pos,
#     767         **response_kw
#     768     )
#     770 # Handle redirect?
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/connectionpool.py:726, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     724     e = ProtocolError("Connection aborted.", e)
# --> 726 retries = retries.increment(
#     727     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728 )
#     729 retries.sleep()
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/urllib3/util/retry.py:446, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     445 if new_retry.is_exhausted():
# --> 446     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     448 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.stubhub.com', port=443): Max retries exceeded with url: /event/150021320 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> listings = get_listings(150021320)
#
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 6 in get_listings(eventid)
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> s = prepare_session()
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a> url = f"https://www.stubhub.com/event/{eventid}"
# ---> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a> url = s.request("POST", url,allow_redirects=True).url
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a> response = s.request("POST", url)
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a> if response.status_code == 404:
#
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 6 in EnhancedSession.request(self, method, url, **kwargs)
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> if "timeout" not in kwargs:
#      <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     kwargs["timeout"] = self.timeout
# ---> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> return super().request(method, url, **kwargs)
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     559         raise ProxyError(e, request=request)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
# --> 563         raise SSLError(e, request=request)
#     565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='www.stubhub.com', port=443): Max retries exceeded with url: /event/150021320 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
listings[0]
# Out:
# {'RatingMessage': None,
#  'RatingValue': 0.0,
#  'Id': 5387535297,
#  'EventId': 150021320,
#  'CssPostFix': 'red2',
#  'TraderType': None,
#  'Section': '132',
#  'SectionId': 100433,
#  'SectionMapName': '',
#  'RowMapName': '',
#  'Row': '26',
#  'Price': '$405',
#  'PriceWithFees': '',
#  'RawPrice': 405.37,
#  'QuantityRange': '2',
#  'IsAlreadySold': False,
#  'IsAlreadySoldTicketClass': None,
#  'LastInSectionString': None,
#  'LastInSectionDescriptionString': None,
#  'AboutToSellOut': None,
#  'AboutToSellOutExplanation': None,
#  'NumberOfTicketsString': None,
#  'AdmitXTicketsString': None,
#  'TicketsLeftInListingMessage': None,
#  'ShowNumberOfTicketsString': False,
#  'LastTicketsInSectionMessage': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None},
#  'NumberOfTicketsDisplayed': None,
#  'WillBeAnimated': True,
#  'LocationRank': 0.0,
#  'ListingRank': 0.0,
#  'PriceRank': 0.0,
#  'SectionColor': None,
#  'HasBestValue': False,
#  'IsPromotedListing': False,
#  'SwapMapInTile': False,
#  'ShowStandOrSitFreely': None,
#  'PreAllocatedSeats': None,
#  'PriceBucketColour': '#a3d165',
#  'PriceBucketColourClass': None,
#  'GeneralAdmissionExplanation': None,
#  'IsGeneralAdmission': False,
#  'FaceValueText': None,
#  'MaxQuantity': 2,
#  'SourceId': None,
#  'AvailableQuantities': [2],
#  'TicketTypeNotes': 'E-Ticket',
#  'TicketTypeNotesAndListingNotesSeparator': '<br />',
#  'TicketClass': 1353,
#  'TicketClassName': 'Category 9',
#  'BuyUrl': '/secure/buy/Initialise?ListingID=5387535297&EventID=150021320&CategoryId=5816&Quantity=2',
#  'PackageTitle': None,
#  'Package': None,
#  'Seats': None,
#  'IsRationalizedListing': True,
#  'ShowInstantDownloadBadge': False,
#  'RowId': 435742,
#  'IsUsersListing': False,
#  'TicketReservationContent': None,
#  'IsCheapestInSection': None,
#  'IsCheapestInTicketClass': False,
#  'IsBestValueInTicketClass': False,
#  'ShowStandingTogetherBadge': False,
#  'ShowReservedSeatsBadge': False,
#  'ShowPeopleViewed': False,
#  'PeopleViewedMessage': None,
#  'IsBestDealInSection': False,
#  'ShowLastTicketsAtThisPriceMessage': False,
#  'IsRecommendedByUs': False,
#  'SvgMapPngUrl': 'https://img.vggcdn.net/img/vpng/347011/3/4/100433.png',
#  'SvgMapPngTcFallbackUrl': 'https://img.vggcdn.net/img/vpng/347011/3/4/tc_1353.png',
#  'HottestTicketMessage': None,
#  'PeopleViewingMessage': None,
#  'IsSellingFast': False,
#  'ShowExpressHomeDeliveryBadge': False,
#  'IsDiscounted': False,
#  'WillKickUser': False,
#  'TicketTypeId': 1,
#  'TicketTypesWithIcons': None,
#  'TicketTypeForPageEvent': None,
#  'ShowClickAndDownloadMessage': None,
#  'XOtherInterestedInBadgeText': None,
#  'XOthersInterestedInTicketsMessage': None,
#  'ListingNoteSectionTitle': None,
#  'IsReservedListing': False,
#  'NowAtPrice': None,
#  'othersViewingTheseTicketsMessage': None,
#  'CountryCode': None,
#  'HumanFilterIds': None,
#  'RestrictionListingNotes': None,
#  'RecommendReason': None,
#  'IsCheapest': False,
#  'RecentlyAddedString': None,
#  'RecentlySoldTicketCountString': None,
#  'SeatInfo': None,
#  'HasBadListingNotes': False,
#  'CanBeCompared': False,
#  'LocationRanking': 0.0,
#  'LocationRankingMessage': None,
#  'AlternativeListingMessage': None,
#  'ListingNotes': [{'ListingNoteId': -1,
#    'ListingNoteContentId': 1523411,
#    'FormattedListingNoteContent': 'Unrestricted view.',
#    'ListingNoteTypeId': 3,
#    'ShowToBuyer': True,
#    'HideInMock': False,
#    'FormattedListingNoteQualifier': None,
#    'ListingNoteDescriptionContentId': 1319276,
#    'FormattedListingNoteDescription': "You'll have a clear view of the show.",
#    'IconOverride': None}],
#  'PreRenderedTicketTypeNotesAndListingNotes': [{'ListingNoteId': -1,
#    'ListingNoteContentId': 1523411,
#    'FormattedListingNoteContent': 'Unrestricted view.',
#    'ListingNoteTypeId': 3,
#    'ShowToBuyer': True,
#    'HideInMock': False,
#    'FormattedListingNoteQualifier': None,
#    'ListingNoteDescriptionContentId': 1319276,
#    'FormattedListingNoteDescription': "You'll have a clear view of the show.",
#    'IconOverride': None}],
#  'MostPopularSectionDescription': None,
#  'ViewFromSectionUrl': None,
#  'ViewFromSeatUrl': None,
#  'ViewFromSectionDisclaimer': None,
#  'RemoveAnimation': False,
#  'DistinctPriceTicketContent': None,
#  'MaySoonChangePriceMessage': None,
#  'CheapestInSectionMessage': None,
#  'SectionSellingFastMessage': None,
#  'SeasonalDealMessage': None,
#  'SeasonalDealClass': None,
#  'SeasonalDealExplanation': None,
#  'MonthlyDealMessage': None,
#  'MonthlyDealDescription': None,
#  'SellerIsNearbyMessage': None,
#  'SoldXTimeAgoSiteMessage': {'Message': 'Sold',
#   'Qualifier': '12 hours ago',
#   'Disclaimer': None,
#   'HasValue': True,
#   'FeatureTrackingKey': '8fce4fde-33bb-4ed7-b007-21ffd58fb113'},
#  'RowContent': 'Row',
#  'XPercentageOfPeopleBoughtThisSection': None,
#  'XPercentageOfPeopleBoughtThisSectionExplanation': None,
#  'EmailDeliveryMessage': None,
#  'ExpiresMessage': None,
#  'ExpiresMessageDisclaimer': None,
#  'AlternativeOffer': None,
#  'SectionRecentlySoldCount': 0,
#  'ShowSeatedTogetherBulletAsChairs': False,
#  'IsSeatedTogether': True,
#  'PipelineEntryMessage': None,
#  'GoldenListingPowerUp': False,
#  'StarDecorationPowerUp': False,
#  'DisplayPrice': 405.0,
#  'IsLocked': False,
#  'LockedTimeSeconds': 0,
#  'NoParticipationLocked': False,
#  'HasSeatInformation': True,
#  'SectionLikelyToSellOutMessage': None,
#  'BestSellingInSectionMessage': None,
#  'CheapestInCityMessage': None,
#  'HasSpecialNotes': False,
#  'IsExpertChoice': False,
#  'IsStandardTicket': False,
#  'FaceValueMessage': None,
#  'SellerTrackingKey': None,
#  'FvTrackingKey': None,
#  'InvalidSeatsTrackingKey': None,
#  'TraderIconMessage': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None},
#  'ConnectedSellerIconMessage': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None},
#  'SeatDetailsIcon': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None}}

# %%
ids = [a['Id'] for a in listings]
len(ids)
# Out:
# 499

# %%
DATA_FOLDER = 'data/nba'
LEAGUE = 'NBA'

# get list of events if does not exist
event_files = list(reversed(sorted([f for f in os.listdir(DATA_FOLDER) if 'events' in f])))
if len(event_files) > 0:
    with open(os.path.join(DATA_FOLDER,event_files[0])) as f:
        evs = json.load(f)
else:
    evs = get_events(LEAGUE)
    with open(os.path.join(DATA_FOLDER,f'events_{int(time.time())}.json'), 'w+') as f:
        json.dump(evs,f)

# get listings
retrieve_time = int(time.time())
for e in tqdm(evs):
    listings = get_listings(e['eventId'])
    if listings == None or len(listings) == 0:
        listings = get_listings(e['eventid_from_url'])
    if listings != None and len(listings) > 0:
        with open(os.path.join(DATA_FOLDER,f'listings/{e["eventId"]}_{retrieve_time}.json'), 'w', encoding='utf-8') as f:
            json.dump(listings, f, ensure_ascii=False)

# %%
DATA_FOLDER = 'data/nfl'
LEAGUE = 'NFL'

# get list of events if does not exist
event_files = list(reversed(sorted([f for f in os.listdir(DATA_FOLDER) if 'events' in f])))
if len(event_files) > 0:
    with open(os.path.join(DATA_FOLDER,event_files[0])) as f:
        evs = json.load(f)
else:
    evs = get_events(LEAGUE)
    with open(os.path.join(DATA_FOLDER,f'events_{int(time.time())}.json'), 'w+') as f:
        json.dump(evs,f)

# get listings
retrieve_time = int(time.time())
for e in tqdm(evs):
    listings = get_listings(e['eventId'])
    if listings == None or len(listings) == 0:
        listings = get_listings(e['eventid_from_url'])
    if listings != None and len(listings) > 0:
        with open(os.path.join(DATA_FOLDER,f'listings/{e["eventId"]}_{retrieve_time}.json'), 'w', encoding='utf-8') as f:
            json.dump(listings, f, ensure_ascii=False)
# Out:
#   4%|▎         | 6/166 [00:19<08:38,  3.24s/it]
# 404, Probably, no listings for event 9525140
# https://www.stubhub.com/event/9525140
#   5%|▌         | 9/166 [00:36<12:26,  4.76s/it]
# 404, Probably, no listings for event 9681631
# https://www.stubhub.com/event/9681631
#   8%|▊         | 13/166 [01:02<16:43,  6.56s/it]
# 404, Probably, no listings for event 9592614
# https://www.stubhub.com/event/9592614
#  11%|█         | 18/166 [01:37<16:13,  6.58s/it]
# 404, Probably, no listings for event 9592445
# https://www.stubhub.com/event/9592445
#  11%|█▏        | 19/166 [01:47<19:07,  7.81s/it]
# 404, Probably, no listings for event 9681627
# https://www.stubhub.com/event/9681627
#  13%|█▎        | 21/166 [02:12<25:11, 10.43s/it]
# 404, Probably, no listings for event 9524535
# https://www.stubhub.com/event/9524535
#  14%|█▍        | 23/166 [02:21<17:54,  7.51s/it]
# 404, Probably, no listings for event 9583520
# https://www.stubhub.com/event/9583520
#  14%|█▍        | 24/166 [02:29<18:07,  7.66s/it]
# 404, Probably, no listings for event 9509294
# https://www.stubhub.com/event/9509294
#  17%|█▋        | 29/166 [03:11<14:42,  6.44s/it]
# 404, Probably, no listings for event 9509105
# https://www.stubhub.com/event/9509105
#  21%|██        | 35/166 [04:11<21:54, 10.03s/it]
# 404, Probably, no listings for event 9525147
# https://www.stubhub.com/event/9525147
#  22%|██▏       | 37/166 [04:31<22:20, 10.39s/it]
# 404, Probably, no listings for event 9524578
# https://www.stubhub.com/event/9524578
#  24%|██▍       | 40/166 [04:47<14:19,  6.82s/it]
# 404, Probably, no listings for event 9583695
# https://www.stubhub.com/event/9583695
#  25%|██▍       | 41/166 [05:07<22:13, 10.67s/it]
# 404, Probably, no listings for event 9584041
# https://www.stubhub.com/event/9584041
#  28%|██▊       | 47/166 [06:00<14:55,  7.53s/it]
# 404, Probably, no listings for event 9522639
# https://www.stubhub.com/event/9522639
#  32%|███▏      | 53/166 [07:14<11:00,  5.84s/it]
# 404, Probably, no listings for event 9681629
# https://www.stubhub.com/event/9681629
#  34%|███▍      | 57/166 [07:58<19:22, 10.67s/it]
# 404, Probably, no listings for event 9681653
# https://www.stubhub.com/new-york-mets-tickets/performer/5649/
#  37%|███▋      | 62/166 [08:39<16:25,  9.47s/it]
# 404, Probably, no listings for event 9592620
# https://www.stubhub.com/event/9592620
#  38%|███▊      | 63/166 [08:50<17:18, 10.08s/it]
# 404, Probably, no listings for event 9509111
# https://www.stubhub.com/event/9509111
#  39%|███▉      | 65/166 [09:05<14:25,  8.57s/it]
# 404, Probably, no listings for event 9525144
# https://www.stubhub.com/event/9525144
#  42%|████▏     | 70/166 [10:14<24:50, 15.52s/it]
# 404, Probably, no listings for event 9509112
# https://www.stubhub.com/event/9509112
#  46%|████▌     | 76/166 [11:34<18:42, 12.47s/it]
# 404, Probably, no listings for event 9509441
# https://www.stubhub.com/event/9509441
#  46%|████▋     | 77/166 [11:55<22:24, 15.10s/it]
# 404, Probably, no listings for event 9583515
# https://www.stubhub.com/event/9583515
#  48%|████▊     | 79/166 [12:08<15:15, 10.52s/it]
# 404, Probably, no listings for event 9522811
# https://www.stubhub.com/event/9522811
#  49%|████▉     | 81/166 [13:13<27:49, 19.64s/it]
# 404, Probably, no listings for event 9509459
# https://www.stubhub.com/event/9509459
#  50%|█████     | 83/166 [13:43<22:31, 16.28s/it]
# 404, Probably, no listings for event 9522810
# https://www.stubhub.com/event/9522810
#  52%|█████▏    | 86/166 [14:37<19:24, 14.56s/it]
# 404, Probably, no listings for event 9524582
# https://www.stubhub.com/event/9524582
#  54%|█████▎    | 89/166 [15:05<14:56, 11.64s/it]
# 404, Probably, no listings for event 9583711
# https://www.stubhub.com/event/9583711
#  55%|█████▌    | 92/166 [15:48<15:47, 12.80s/it]
# 404, Probably, no listings for event 9584040
# https://www.stubhub.com/event/9584040
#  61%|██████    | 101/166 [16:46<12:03, 11.13s/it]
# 404, Probably, no listings for event 9524581
# https://www.stubhub.com/event/9524581
#  62%|██████▏   | 103/166 [17:00<09:29,  9.04s/it]
# 404, Probably, no listings for event 9681639
# https://www.stubhub.com/event/9681639
#  66%|██████▌   | 109/166 [18:33<18:26, 19.42s/it]
# 404, Probably, no listings for event 9583701
# https://www.stubhub.com/event/9583701
#  66%|██████▋   | 110/166 [18:56<19:10, 20.55s/it]
# 404, Probably, no listings for event 9584202
# https://www.stubhub.com/event/9584202
#  67%|██████▋   | 112/166 [19:05<11:04, 12.30s/it]
# 404, Probably, no listings for event 9583687
# https://www.stubhub.com/event/9583687
#  69%|██████▊   | 114/166 [19:25<09:44, 11.23s/it]
# 404, Probably, no listings for event 9681638
# https://www.stubhub.com/event/9681638
#  71%|███████   | 118/166 [19:41<04:29,  5.62s/it]
# 404, Probably, no listings for event 9592621
# https://www.stubhub.com/event/9592621
#  73%|███████▎  | 122/166 [21:20<14:45, 20.12s/it]
# 404, Probably, no listings for event 9524754
# https://www.stubhub.com/event/9524754
#  76%|███████▌  | 126/166 [23:08<18:21, 27.53s/it]
# 404, Probably, no listings for event 9522806
# https://www.stubhub.com/event/9522806
#  77%|███████▋  | 128/166 [24:37<21:45, 34.35s/it]
# 404, Probably, no listings for event 9681626
# https://www.stubhub.com/event/9681626
#  78%|███████▊  | 129/166 [24:50<17:16, 28.03s/it]
# 404, Probably, no listings for event 9509462
# https://www.stubhub.com/event/9509462
#  81%|████████▏ | 135/166 [26:04<07:33, 14.64s/it]
# 404, Probably, no listings for event 9525145
# https://www.stubhub.com/event/9525145
#  84%|████████▍ | 140/166 [27:32<07:58, 18.39s/it]
# 404, Probably, no listings for event 9509284
# https://www.stubhub.com/event/9509284
#  86%|████████▌ | 143/166 [28:17<06:28, 16.90s/it]
# 404, Probably, no listings for event 9525145
# https://www.stubhub.com/event/9525145
#  87%|████████▋ | 144/166 [28:28<05:32, 15.14s/it]
# 404, Probably, no listings for event 9583623
# https://www.stubhub.com/event/9583623
#  89%|████████▊ | 147/166 [28:48<03:03,  9.64s/it]
# 404, Probably, no listings for event 9583703
# https://www.stubhub.com/event/9583703
#  90%|█████████ | 150/166 [29:20<02:42, 10.15s/it]
# 404, Probably, no listings for event 9524580
# https://www.stubhub.com/event/9524580
#  93%|█████████▎| 155/166 [30:21<02:28, 13.49s/it]
# 404, Probably, no listings for event 9509093
# https://www.stubhub.com/florida-georgia-line-tickets/performer/706722/
#  94%|█████████▍| 156/166 [30:45<02:44, 16.46s/it]
# 404, Probably, no listings for event 9681621
# https://www.stubhub.com/event/9681621
#  97%|█████████▋| 161/166 [32:46<02:06, 25.37s/it]
# 404, Probably, no listings for event 9584042
# https://www.stubhub.com/event/9584042
#  99%|█████████▉| 164/166 [33:30<00:36, 18.48s/it]
# 404, Probably, no listings for event 9583509
# https://www.stubhub.com/event/9583509
# 100%|██████████| 166/166 [33:46<00:00, 12.21s/it]

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_json('data/nba/listings/150339092_1667282312.json')
df.describe()
# Out:
#        RatingMessage  RatingValue            Id      EventId  TraderType  \
# count            0.0       1313.0  1.313000e+03       1313.0         0.0
# mean             NaN          0.0  5.544865e+09  150339092.0         NaN
# std              NaN          0.0  6.759717e+07          0.0         NaN
# min              NaN          0.0  5.442922e+09  150339092.0         NaN
# 25%              NaN          0.0  5.462843e+09  150339092.0         NaN
# 50%              NaN          0.0  5.580010e+09  150339092.0         NaN
# 75%              NaN          0.0  5.606492e+09  150339092.0         NaN
# max              NaN          0.0  5.616581e+09  150339092.0         NaN
#
#           SectionId     RawPrice  IsAlreadySold  IsAlreadySoldTicketClass  \
# count  1.300000e+03  1313.000000          189.0                       0.0
# mean   1.217728e+06   291.337281            0.0                       NaN
# std    1.559571e+05   417.806801            0.0                       NaN
# min    1.132924e+06    31.500000            0.0                       NaN
# 25%    1.133336e+06   133.250000            0.0                       NaN
# 50%    1.133534e+06   200.900000            0.0                       NaN
# 75%    1.133545e+06   318.470000            0.0                       NaN
# max    1.716098e+06  7577.680000            0.0                       NaN
#
#        LastInSectionString  LastInSectionDescriptionString  AboutToSellOut  \
# count                  0.0                             0.0             0.0
# mean                   NaN                             NaN             NaN
# std                    NaN                             NaN             NaN
# min                    NaN                             NaN             NaN
# 25%                    NaN                             NaN             NaN
# 50%                    NaN                             NaN             NaN
# 75%                    NaN                             NaN             NaN
# max                    NaN                             NaN             NaN
#
#        AboutToSellOutExplanation  NumberOfTicketsString  AdmitXTicketsString  \
# count                        0.0                    0.0                  0.0
# mean                         NaN                    NaN                  NaN
# std                          NaN                    NaN                  NaN
# min                          NaN                    NaN                  NaN
# 25%                          NaN                    NaN                  NaN
# 50%                          NaN                    NaN                  NaN
# 75%                          NaN                    NaN                  NaN
# max                          NaN                    NaN                  NaN
#
#        NumberOfTicketsDisplayed  LocationRank  ListingRank  PriceRank  \
# count                       0.0        1313.0       1313.0     1313.0
# mean                        NaN           0.0          0.0        0.0
# std                         NaN           0.0          0.0        0.0
# min                         NaN           0.0          0.0        0.0
# 25%                         NaN           0.0          0.0        0.0
# 50%                         NaN           0.0          0.0        0.0
# 75%                         NaN           0.0          0.0        0.0
# max                         NaN           0.0          0.0        0.0
#
#        SectionColor  ShowStandOrSitFreely  PreAllocatedSeats  \
# count           0.0                   0.0                0.0
# mean            NaN                   NaN                NaN
# std             NaN                   NaN                NaN
# min             NaN                   NaN                NaN
# 25%             NaN                   NaN                NaN
# 50%             NaN                   NaN                NaN
# 75%             NaN                   NaN                NaN
# max             NaN                   NaN                NaN
#
#        PriceBucketColourClass  GeneralAdmissionExplanation  FaceValueText  \
# count                     0.0                          0.0            0.0
# mean                      NaN                          NaN            NaN
# std                       NaN                          NaN            NaN
# min                       NaN                          NaN            NaN
# 25%                       NaN                          NaN            NaN
# 50%                       NaN                          NaN            NaN
# 75%                       NaN                          NaN            NaN
# max                       NaN                          NaN            NaN
#
#        MaxQuantity  SourceId   TicketClass  PackageTitle  Package  Seats  \
# count  1313.000000       0.0   1313.000000           0.0      0.0    0.0
# mean      2.718203       NaN   2328.449353           NaN      NaN    NaN
# std       1.636506       NaN   2071.654580           NaN      NaN    NaN
# min       1.000000       NaN      0.000000           NaN      NaN    NaN
# 25%       2.000000       NaN    954.000000           NaN      NaN    NaN
# 50%       2.000000       NaN   1687.000000           NaN      NaN    NaN
# 75%       4.000000       NaN   1713.000000           NaN      NaN    NaN
# max      13.000000       NaN  17206.000000           NaN      NaN    NaN
#
#               RowId  TicketReservationContent  IsCheapestInSection  \
# count  1.300000e+03                       0.0                  0.0
# mean   8.629315e+05                       NaN                  NaN
# std    5.453635e+05                       NaN                  NaN
# min    5.412190e+05                       NaN                  NaN
# 25%    5.420215e+05                       NaN                  NaN
# 50%    5.432095e+05                       NaN                  NaN
# 75%    1.472475e+06                       NaN                  NaN
# max    2.176594e+06                       NaN                  NaN
#
#        PeopleViewedMessage  HottestTicketMessage  PeopleViewingMessage  \
# count                  0.0                   0.0                   0.0
# mean                   NaN                   NaN                   NaN
# std                    NaN                   NaN                   NaN
# min                    NaN                   NaN                   NaN
# 25%                    NaN                   NaN                   NaN
# 50%                    NaN                   NaN                   NaN
# 75%                    NaN                   NaN                   NaN
# max                    NaN                   NaN                   NaN
#
#        TicketTypeId  TicketTypesWithIcons  TicketTypeForPageEvent  \
# count   1313.000000                   0.0                     0.0
# mean       9.486672                   NaN                     NaN
# std        1.781086                   NaN                     NaN
# min        0.000000                   NaN                     NaN
# 25%       10.000000                   NaN                     NaN
# 50%       10.000000                   NaN                     NaN
# 75%       10.000000                   NaN                     NaN
# max       10.000000                   NaN                     NaN
#
#        ShowClickAndDownloadMessage  XOtherInterestedInBadgeText  \
# count                          0.0                          0.0
# mean                           NaN                          NaN
# std                            NaN                          NaN
# min                            NaN                          NaN
# 25%                            NaN                          NaN
# 50%                            NaN                          NaN
# 75%                            NaN                          NaN
# max                            NaN                          NaN
#
#        XOthersInterestedInTicketsMessage  ListingNoteSectionTitle  NowAtPrice  \
# count                                0.0                      0.0         0.0
# mean                                 NaN                      NaN         NaN
# std                                  NaN                      NaN         NaN
# min                                  NaN                      NaN         NaN
# 25%                                  NaN                      NaN         NaN
# 50%                                  NaN                      NaN         NaN
# 75%                                  NaN                      NaN         NaN
# max                                  NaN                      NaN         NaN
#
#        othersViewingTheseTicketsMessage  CountryCode  HumanFilterIds  \
# count                               0.0          0.0             0.0
# mean                                NaN          NaN             NaN
# std                                 NaN          NaN             NaN
# min                                 NaN          NaN             NaN
# 25%                                 NaN          NaN             NaN
# 50%                                 NaN          NaN             NaN
# 75%                                 NaN          NaN             NaN
# max                                 NaN          NaN             NaN
#
#        RestrictionListingNotes  RecommendReason  RecentlyAddedString  \
# count                      0.0              0.0                  0.0
# mean                       NaN              NaN                  NaN
# std                        NaN              NaN                  NaN
# min                        NaN              NaN                  NaN
# 25%                        NaN              NaN                  NaN
# 50%                        NaN              NaN                  NaN
# 75%                        NaN              NaN                  NaN
# max                        NaN              NaN                  NaN
#
#        RecentlySoldTicketCountString  SeatInfo  LocationRanking  \
# count                            0.0       0.0           1313.0
# mean                             NaN       NaN              0.0
# std                              NaN       NaN              0.0
# min                              NaN       NaN              0.0
# 25%                              NaN       NaN              0.0
# 50%                              NaN       NaN              0.0
# 75%                              NaN       NaN              0.0
# max                              NaN       NaN              0.0
#
#        LocationRankingMessage  AlternativeListingMessage  \
# count                     0.0                        0.0
# mean                      NaN                        NaN
# std                       NaN                        NaN
# min                       NaN                        NaN
# 25%                       NaN                        NaN
# 50%                       NaN                        NaN
# 75%                       NaN                        NaN
# max                       NaN                        NaN
#
#        MostPopularSectionDescription  ViewFromSectionUrl  ViewFromSeatUrl  \
# count                            0.0                 0.0              0.0
# mean                             NaN                 NaN              NaN
# std                              NaN                 NaN              NaN
# min                              NaN                 NaN              NaN
# 25%                              NaN                 NaN              NaN
# 50%                              NaN                 NaN              NaN
# 75%                              NaN                 NaN              NaN
# max                              NaN                 NaN              NaN
#
#        ViewFromSectionDisclaimer  DistinctPriceTicketContent  \
# count                        0.0                         0.0
# mean                         NaN                         NaN
# std                          NaN                         NaN
# min                          NaN                         NaN
# 25%                          NaN                         NaN
# 50%                          NaN                         NaN
# 75%                          NaN                         NaN
# max                          NaN                         NaN
#
#        MaySoonChangePriceMessage  CheapestInSectionMessage  \
# count                        0.0                       0.0
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#        SectionSellingFastMessage  SeasonalDealMessage  SeasonalDealClass  \
# count                        0.0                  0.0                0.0
# mean                         NaN                  NaN                NaN
# std                          NaN                  NaN                NaN
# min                          NaN                  NaN                NaN
# 25%                          NaN                  NaN                NaN
# 50%                          NaN                  NaN                NaN
# 75%                          NaN                  NaN                NaN
# max                          NaN                  NaN                NaN
#
#        SeasonalDealExplanation  MonthlyDealMessage  MonthlyDealDescription  \
# count                      0.0                 0.0                     0.0
# mean                       NaN                 NaN                     NaN
# std                        NaN                 NaN                     NaN
# min                        NaN                 NaN                     NaN
# 25%                        NaN                 NaN                     NaN
# 50%                        NaN                 NaN                     NaN
# 75%                        NaN                 NaN                     NaN
# max                        NaN                 NaN                     NaN
#
#        SellerIsNearbyMessage  XPercentageOfPeopleBoughtThisSection  \
# count                    0.0                                   0.0
# mean                     NaN                                   NaN
# std                      NaN                                   NaN
# min                      NaN                                   NaN
# 25%                      NaN                                   NaN
# 50%                      NaN                                   NaN
# 75%                      NaN                                   NaN
# max                      NaN                                   NaN
#
#        XPercentageOfPeopleBoughtThisSectionExplanation  EmailDeliveryMessage  \
# count                                              0.0                   0.0
# mean                                               NaN                   NaN
# std                                                NaN                   NaN
# min                                                NaN                   NaN
# 25%                                                NaN                   NaN
# 50%                                                NaN                   NaN
# 75%                                                NaN                   NaN
# max                                                NaN                   NaN
#
#        ExpiresMessage  ExpiresMessageDisclaimer  AlternativeOffer  \
# count             0.0                       0.0               0.0
# mean              NaN                       NaN               NaN
# std               NaN                       NaN               NaN
# min               NaN                       NaN               NaN
# 25%               NaN                       NaN               NaN
# 50%               NaN                       NaN               NaN
# 75%               NaN                       NaN               NaN
# max               NaN                       NaN               NaN
#
#        SectionRecentlySoldCount  PipelineEntryMessage  DisplayPrice  \
# count                    1313.0                   0.0   1313.000000
# mean                        0.0                   NaN    291.316070
# std                         0.0                   NaN    417.805699
# min                         0.0                   NaN     32.000000
# 25%                         0.0                   NaN    133.000000
# 50%                         0.0                   NaN    201.000000
# 75%                         0.0                   NaN    318.000000
# max                         0.0                   NaN   7578.000000
#
#        LockedTimeSeconds  SectionLikelyToSellOutMessage  \
# count             1313.0                            0.0
# mean                 0.0                            NaN
# std                  0.0                            NaN
# min                  0.0                            NaN
# 25%                  0.0                            NaN
# 50%                  0.0                            NaN
# 75%                  0.0                            NaN
# max                  0.0                            NaN
#
#        CheapestInCityMessage  FaceValueMessage  FvTrackingKey  \
# count                    0.0               0.0            0.0
# mean                     NaN               NaN            NaN
# std                      NaN               NaN            NaN
# min                      NaN               NaN            NaN
# 25%                      NaN               NaN            NaN
# 50%                      NaN               NaN            NaN
# 75%                      NaN               NaN            NaN
# max                      NaN               NaN            NaN
#
#        InvalidSeatsTrackingKey
# count                      0.0
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN

# %%
with open('data/nba/listings/150339092_1667282312.json') as f: 
    j = json.load(f)
j[0]
# Out:
# {'RatingMessage': None,
#  'RatingValue': 0.0,
#  'Id': 5575812083,
#  'EventId': 150339092,
#  'CssPostFix': '',
#  'TraderType': None,
#  'Section': 'PARKINGING',
#  'SectionId': None,
#  'SectionMapName': '',
#  'RowMapName': '$r',
#  'Row': None,
#  'Price': '$32',
#  'PriceWithFees': '$40',
#  'RawPrice': 31.5,
#  'QuantityRange': '1',
#  'IsAlreadySold': None,
#  'IsAlreadySoldTicketClass': None,
#  'LastInSectionString': None,
#  'LastInSectionDescriptionString': None,
#  'AboutToSellOut': None,
#  'AboutToSellOutExplanation': None,
#  'NumberOfTicketsString': None,
#  'AdmitXTicketsString': None,
#  'TicketsLeftInListingMessage': {'Message': '1 ticket remaining',
#   'Qualifier': 'in this listing',
#   'Disclaimer': None,
#   'HasValue': True,
#   'FeatureTrackingKey': '2fbb0992-0355-42c8-98d2-4f0616842abb'},
#  'ShowNumberOfTicketsString': False,
#  'LastTicketsInSectionMessage': None,
#  'NumberOfTicketsDisplayed': None,
#  'WillBeAnimated': False,
#  'LocationRank': 0.0,
#  'ListingRank': 0.0,
#  'PriceRank': 0.0,
#  'SectionColor': None,
#  'HasBestValue': False,
#  'IsPromotedListing': False,
#  'SwapMapInTile': False,
#  'ShowStandOrSitFreely': None,
#  'PreAllocatedSeats': None,
#  'PriceBucketColour': '#a3d165',
#  'PriceBucketColourClass': None,
#  'GeneralAdmissionExplanation': None,
#  'IsGeneralAdmission': False,
#  'FaceValueText': None,
#  'MaxQuantity': 1,
#  'SourceId': None,
#  'AvailableQuantities': [1],
#  'TicketTypeNotes': '',
#  'TicketTypeNotesAndListingNotesSeparator': '<br />',
#  'TicketClass': 0,
#  'TicketClassName': None,
#  'BuyUrl': '/secure/buy/Initialise?ListingID=5575812083&EventID=150339092&CategoryId=5973',
#  'PackageTitle': None,
#  'Package': None,
#  'Seats': None,
#  'IsRationalizedListing': True,
#  'ShowInstantDownloadBadge': False,
#  'RowId': None,
#  'IsUsersListing': False,
#  'TicketReservationContent': None,
#  'IsCheapestInSection': None,
#  'IsCheapestInTicketClass': False,
#  'IsBestValueInTicketClass': False,
#  'ShowStandingTogetherBadge': False,
#  'ShowReservedSeatsBadge': False,
#  'ShowPeopleViewed': False,
#  'PeopleViewedMessage': None,
#  'IsBestDealInSection': False,
#  'ShowLastTicketsAtThisPriceMessage': False,
#  'IsRecommendedByUs': False,
#  'SvgMapPngUrl': 'https://img.vggcdn.net/img/svgpng4/349165/tc_0.png',
#  'SvgMapPngTcFallbackUrl': 'https://img.vggcdn.net/img/svgpng4/349165/tc_0.png',
#  'HottestTicketMessage': None,
#  'PeopleViewingMessage': None,
#  'IsSellingFast': False,
#  'ShowExpressHomeDeliveryBadge': False,
#  'IsDiscounted': False,
#  'WillKickUser': False,
#  'TicketTypeId': 10,
#  'TicketTypesWithIcons': None,
#  'TicketTypeForPageEvent': None,
#  'ShowClickAndDownloadMessage': None,
#  'XOtherInterestedInBadgeText': None,
#  'XOthersInterestedInTicketsMessage': None,
#  'ListingNoteSectionTitle': None,
#  'IsReservedListing': False,
#  'NowAtPrice': None,
#  'othersViewingTheseTicketsMessage': None,
#  'CountryCode': None,
#  'HumanFilterIds': None,
#  'RestrictionListingNotes': None,
#  'RecommendReason': None,
#  'IsCheapest': False,
#  'RecentlyAddedString': None,
#  'RecentlySoldTicketCountString': None,
#  'SeatInfo': None,
#  'HasBadListingNotes': False,
#  'CanBeCompared': False,
#  'LocationRanking': 0.0,
#  'LocationRankingMessage': None,
#  'AlternativeListingMessage': None,
#  'ListingNotes': [{'ListingNoteId': -1,
#    'ListingNoteContentId': 1523411,
#    'FormattedListingNoteContent': 'Unrestricted view.',
#    'ListingNoteTypeId': 3,
#    'ShowToBuyer': True,
#    'HideInMock': False,
#    'FormattedListingNoteQualifier': None,
#    'ListingNoteDescriptionContentId': 1319276,
#    'FormattedListingNoteDescription': "You'll have a clear view of the show.",
#    'IconOverride': None}],
#  'PreRenderedTicketTypeNotesAndListingNotes': [{'ListingNoteId': -1,
#    'ListingNoteContentId': 1523411,
#    'FormattedListingNoteContent': 'Unrestricted view.',
#    'ListingNoteTypeId': 3,
#    'ShowToBuyer': True,
#    'HideInMock': False,
#    'FormattedListingNoteQualifier': None,
#    'ListingNoteDescriptionContentId': 1319276,
#    'FormattedListingNoteDescription': "You'll have a clear view of the show.",
#    'IconOverride': None}],
#  'MostPopularSectionDescription': None,
#  'ViewFromSectionUrl': None,
#  'ViewFromSeatUrl': None,
#  'ViewFromSectionDisclaimer': None,
#  'RemoveAnimation': False,
#  'DistinctPriceTicketContent': None,
#  'MaySoonChangePriceMessage': None,
#  'CheapestInSectionMessage': None,
#  'SectionSellingFastMessage': None,
#  'SeasonalDealMessage': None,
#  'SeasonalDealClass': None,
#  'SeasonalDealExplanation': None,
#  'MonthlyDealMessage': None,
#  'MonthlyDealDescription': None,
#  'SellerIsNearbyMessage': None,
#  'SoldXTimeAgoSiteMessage': None,
#  'RowContent': 'Row',
#  'XPercentageOfPeopleBoughtThisSection': None,
#  'XPercentageOfPeopleBoughtThisSectionExplanation': None,
#  'EmailDeliveryMessage': None,
#  'ExpiresMessage': None,
#  'ExpiresMessageDisclaimer': None,
#  'AlternativeOffer': None,
#  'SectionRecentlySoldCount': 0,
#  'ShowSeatedTogetherBulletAsChairs': False,
#  'IsSeatedTogether': False,
#  'PipelineEntryMessage': None,
#  'GoldenListingPowerUp': False,
#  'StarDecorationPowerUp': False,
#  'DisplayPrice': 32.0,
#  'IsLocked': False,
#  'LockedTimeSeconds': 0,
#  'NoParticipationLocked': False,
#  'HasSeatInformation': True,
#  'SectionLikelyToSellOutMessage': None,
#  'BestSellingInSectionMessage': None,
#  'CheapestInCityMessage': None,
#  'HasSpecialNotes': True,
#  'IsExpertChoice': False,
#  'IsStandardTicket': False,
#  'FaceValueMessage': None,
#  'SellerTrackingKey': 'e205966f-497c-4d4f-b5f6-6be10d8e63ba',
#  'FvTrackingKey': None,
#  'InvalidSeatsTrackingKey': None,
#  'TraderIconMessage': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None},
#  'ConnectedSellerIconMessage': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None},
#  'SeatDetailsIcon': {'Message': None,
#   'Qualifier': None,
#   'Disclaimer': None,
#   'HasValue': False,
#   'FeatureTrackingKey': None}}

# %%
import os
dfs = [] # an empty list to store the data frames
file_list = [f for f in os.listdir('data/nba/listings/') if '.json' in f]
for file in file_list:
    print(file)
    data = pd.read_json('data/nba/listings/{}'.format(file)) # read data frame from json file
    dfs.append(data) # append the data frame to the list

temp = pd.concat(dfs, ignore_index=True)
temp
# Out:
# 150338343_1667282312.json
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 14 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> for file in file_list:
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     print(file)
# ----> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     data = pd.read_json('data/nba/listings/{}'.format(file)) # read data frame from json file
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>     dfs.append(data) # append the data frame to the list
#       <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> temp = pd.concat(dfs, ignore_index=True)
#
# NameError: name 'pd' is not defined

# %%
temp.describe()
# Out:
#        RatingMessage  RatingValue            Id       EventId  TraderType  \
# count            0.0     381563.0  3.815630e+05  3.815630e+05         0.0
# mean             NaN          0.0  5.538428e+09  1.503446e+08         NaN
# std              NaN          0.0  6.146614e+07  2.051117e+04         NaN
# min              NaN          0.0  5.442877e+09  1.502468e+08         NaN
# 25%              NaN          0.0  5.475478e+09  1.503383e+08         NaN
# 50%              NaN          0.0  5.551211e+09  1.503388e+08         NaN
# 75%              NaN          0.0  5.595985e+09  1.503398e+08         NaN
# max              NaN          0.0  5.616762e+09  1.505270e+08         NaN
#
#           SectionId       RawPrice  IsAlreadySold  IsAlreadySoldTicketClass  \
# count  3.794720e+05  381563.000000        27131.0                       0.0
# mean   7.195838e+05     285.681312            0.0                       NaN
# std    5.867632e+05    1123.550352            0.0                       NaN
# min    6.718500e+04       3.490000            0.0                       NaN
# 25%    1.491440e+05      63.210000            0.0                       NaN
# 50%    2.780550e+05     135.000000            0.0                       NaN
# 75%    1.276539e+06     277.300000            0.0                       NaN
# max    1.728046e+06  225762.950000            0.0                       NaN
#
#        LastInSectionString  LastInSectionDescriptionString  AboutToSellOut  \
# count                  0.0                             0.0             0.0
# mean                   NaN                             NaN             NaN
# std                    NaN                             NaN             NaN
# min                    NaN                             NaN             NaN
# 25%                    NaN                             NaN             NaN
# 50%                    NaN                             NaN             NaN
# 75%                    NaN                             NaN             NaN
# max                    NaN                             NaN             NaN
#
#        AboutToSellOutExplanation  NumberOfTicketsString  AdmitXTicketsString  \
# count                        0.0                    0.0                  0.0
# mean                         NaN                    NaN                  NaN
# std                          NaN                    NaN                  NaN
# min                          NaN                    NaN                  NaN
# 25%                          NaN                    NaN                  NaN
# 50%                          NaN                    NaN                  NaN
# 75%                          NaN                    NaN                  NaN
# max                          NaN                    NaN                  NaN
#
#        NumberOfTicketsDisplayed  LocationRank  ListingRank  PriceRank  \
# count                       0.0      381563.0     381563.0   381563.0
# mean                        NaN           0.0          0.0        0.0
# std                         NaN           0.0          0.0        0.0
# min                         NaN           0.0          0.0        0.0
# 25%                         NaN           0.0          0.0        0.0
# 50%                         NaN           0.0          0.0        0.0
# 75%                         NaN           0.0          0.0        0.0
# max                         NaN           0.0          0.0        0.0
#
#        SectionColor  ShowStandOrSitFreely  PreAllocatedSeats  \
# count           0.0                   0.0                0.0
# mean            NaN                   NaN                NaN
# std             NaN                   NaN                NaN
# min             NaN                   NaN                NaN
# 25%             NaN                   NaN                NaN
# 50%             NaN                   NaN                NaN
# 75%             NaN                   NaN                NaN
# max             NaN                   NaN                NaN
#
#        PriceBucketColourClass  GeneralAdmissionExplanation  FaceValueText  \
# count                     0.0                          0.0            0.0
# mean                      NaN                          NaN            NaN
# std                       NaN                          NaN            NaN
# min                       NaN                          NaN            NaN
# 25%                       NaN                          NaN            NaN
# 50%                       NaN                          NaN            NaN
# 75%                       NaN                          NaN            NaN
# max                       NaN                          NaN            NaN
#
#          MaxQuantity  SourceId    TicketClass  PackageTitle  Package  Seats  \
# count  381563.000000       0.0  381563.000000           0.0      0.0    0.0
# mean        3.785446       NaN    1528.491410           NaN      NaN    NaN
# std         2.450560       NaN    2385.050357           NaN      NaN    NaN
# min         1.000000       NaN       0.000000           NaN      NaN    NaN
# 25%         2.000000       NaN     407.000000           NaN      NaN    NaN
# 50%         3.000000       NaN     594.000000           NaN      NaN    NaN
# 75%         5.000000       NaN    1687.000000           NaN      NaN    NaN
# max        40.000000       NaN   17428.000000           NaN      NaN    NaN
#
#               RowId  TicketReservationContent  IsCheapestInSection  \
# count  3.794720e+05                       0.0                  0.0
# mean   1.211120e+06                       NaN                  NaN
# std    6.615392e+05                       NaN                  NaN
# min    3.100600e+04                       NaN                  NaN
# 25%    5.430610e+05                       NaN                  NaN
# 50%    1.327669e+06                       NaN                  NaN
# 75%    1.827598e+06                       NaN                  NaN
# max    2.502158e+06                       NaN                  NaN
#
#        PeopleViewedMessage  HottestTicketMessage  PeopleViewingMessage  \
# count                  0.0                   0.0                   0.0
# mean                   NaN                   NaN                   NaN
# std                    NaN                   NaN                   NaN
# min                    NaN                   NaN                   NaN
# 25%                    NaN                   NaN                   NaN
# 50%                    NaN                   NaN                   NaN
# 75%                    NaN                   NaN                   NaN
# max                    NaN                   NaN                   NaN
#
#         TicketTypeId  TicketTypesWithIcons  TicketTypeForPageEvent  \
# count  381563.000000                   0.0                     0.0
# mean        8.198719                   NaN                     NaN
# std         3.723734                   NaN                     NaN
# min         0.000000                   NaN                     NaN
# 25%        10.000000                   NaN                     NaN
# 50%        10.000000                   NaN                     NaN
# 75%        10.000000                   NaN                     NaN
# max        20.000000                   NaN                     NaN
#
#        ShowClickAndDownloadMessage  XOtherInterestedInBadgeText  \
# count                          0.0                          0.0
# mean                           NaN                          NaN
# std                            NaN                          NaN
# min                            NaN                          NaN
# 25%                            NaN                          NaN
# 50%                            NaN                          NaN
# 75%                            NaN                          NaN
# max                            NaN                          NaN
#
#        ListingNoteSectionTitle  NowAtPrice  othersViewingTheseTicketsMessage  \
# count                      0.0         0.0                               0.0
# mean                       NaN         NaN                               NaN
# std                        NaN         NaN                               NaN
# min                        NaN         NaN                               NaN
# 25%                        NaN         NaN                               NaN
# 50%                        NaN         NaN                               NaN
# 75%                        NaN         NaN                               NaN
# max                        NaN         NaN                               NaN
#
#        CountryCode  HumanFilterIds  RestrictionListingNotes  RecommendReason  \
# count          0.0             0.0                      0.0              0.0
# mean           NaN             NaN                      NaN              NaN
# std            NaN             NaN                      NaN              NaN
# min            NaN             NaN                      NaN              NaN
# 25%            NaN             NaN                      NaN              NaN
# 50%            NaN             NaN                      NaN              NaN
# 75%            NaN             NaN                      NaN              NaN
# max            NaN             NaN                      NaN              NaN
#
#        RecentlyAddedString  RecentlySoldTicketCountString  SeatInfo  \
# count                  0.0                            0.0       0.0
# mean                   NaN                            NaN       NaN
# std                    NaN                            NaN       NaN
# min                    NaN                            NaN       NaN
# 25%                    NaN                            NaN       NaN
# 50%                    NaN                            NaN       NaN
# 75%                    NaN                            NaN       NaN
# max                    NaN                            NaN       NaN
#
#        LocationRanking  LocationRankingMessage  AlternativeListingMessage  \
# count         381563.0                     0.0                        0.0
# mean               0.0                     NaN                        NaN
# std                0.0                     NaN                        NaN
# min                0.0                     NaN                        NaN
# 25%                0.0                     NaN                        NaN
# 50%                0.0                     NaN                        NaN
# 75%                0.0                     NaN                        NaN
# max                0.0                     NaN                        NaN
#
#        MostPopularSectionDescription  ViewFromSectionUrl  ViewFromSeatUrl  \
# count                            0.0                 0.0              0.0
# mean                             NaN                 NaN              NaN
# std                              NaN                 NaN              NaN
# min                              NaN                 NaN              NaN
# 25%                              NaN                 NaN              NaN
# 50%                              NaN                 NaN              NaN
# 75%                              NaN                 NaN              NaN
# max                              NaN                 NaN              NaN
#
#        ViewFromSectionDisclaimer  DistinctPriceTicketContent  \
# count                        0.0                         0.0
# mean                         NaN                         NaN
# std                          NaN                         NaN
# min                          NaN                         NaN
# 25%                          NaN                         NaN
# 50%                          NaN                         NaN
# 75%                          NaN                         NaN
# max                          NaN                         NaN
#
#        MaySoonChangePriceMessage  CheapestInSectionMessage  \
# count                        0.0                       0.0
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#        SectionSellingFastMessage  SeasonalDealMessage  SeasonalDealClass  \
# count                        0.0                  0.0                0.0
# mean                         NaN                  NaN                NaN
# std                          NaN                  NaN                NaN
# min                          NaN                  NaN                NaN
# 25%                          NaN                  NaN                NaN
# 50%                          NaN                  NaN                NaN
# 75%                          NaN                  NaN                NaN
# max                          NaN                  NaN                NaN
#
#        SeasonalDealExplanation  MonthlyDealMessage  MonthlyDealDescription  \
# count                      0.0                 0.0                     0.0
# mean                       NaN                 NaN                     NaN
# std                        NaN                 NaN                     NaN
# min                        NaN                 NaN                     NaN
# 25%                        NaN                 NaN                     NaN
# 50%                        NaN                 NaN                     NaN
# 75%                        NaN                 NaN                     NaN
# max                        NaN                 NaN                     NaN
#
#        SellerIsNearbyMessage  XPercentageOfPeopleBoughtThisSection  \
# count                    0.0                                   0.0
# mean                     NaN                                   NaN
# std                      NaN                                   NaN
# min                      NaN                                   NaN
# 25%                      NaN                                   NaN
# 50%                      NaN                                   NaN
# 75%                      NaN                                   NaN
# max                      NaN                                   NaN
#
#        XPercentageOfPeopleBoughtThisSectionExplanation  EmailDeliveryMessage  \
# count                                              0.0                   0.0
# mean                                               NaN                   NaN
# std                                                NaN                   NaN
# min                                                NaN                   NaN
# 25%                                                NaN                   NaN
# 50%                                                NaN                   NaN
# 75%                                                NaN                   NaN
# max                                                NaN                   NaN
#
#        ExpiresMessage  ExpiresMessageDisclaimer  AlternativeOffer  \
# count             0.0                       0.0               0.0
# mean              NaN                       NaN               NaN
# std               NaN                       NaN               NaN
# min               NaN                       NaN               NaN
# 25%               NaN                       NaN               NaN
# 50%               NaN                       NaN               NaN
# 75%               NaN                       NaN               NaN
# max               NaN                       NaN               NaN
#
#        SectionRecentlySoldCount  PipelineEntryMessage   DisplayPrice  \
# count                  381563.0                   0.0  381563.000000
# mean                        0.0                   NaN     285.674942
# std                         0.0                   NaN    1123.551640
# min                         0.0                   NaN       3.000000
# 25%                         0.0                   NaN      63.000000
# 50%                         0.0                   NaN     135.000000
# 75%                         0.0                   NaN     277.000000
# max                         0.0                   NaN  225763.000000
#
#        LockedTimeSeconds  FaceValueMessage  FvTrackingKey  \
# count           381563.0               0.0            0.0
# mean                 0.0               NaN            NaN
# std                  0.0               NaN            NaN
# min                  0.0               NaN            NaN
# 25%                  0.0               NaN            NaN
# 50%                  0.0               NaN            NaN
# 75%                  0.0               NaN            NaN
# max                  0.0               NaN            NaN
#
#        InvalidSeatsTrackingKey
# count                      0.0
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN

# %%
temp['RowMapName'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/i31145/Desktop/misc/listing-scraper/src/st/test.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> temp['RowMapName'].unique()
#
# NameError: name 'temp' is not defined

# %%
{'RatingMessage': None,
 'RatingValue': 0.0,
 'Id': 5575812083,
 'EventId': 150339092,
 'Section': 'PARKINGING',
 'SectionId': None,
 'SectionMapName': '',
 'RowMapName': '$r',
 'Row': None,
 'Price': '$32',
 'PriceWithFees': '$40',
 'RawPrice': 31.5,
 'QuantityRange': '1',
 'MaxQuantity': 1,
 'AvailableQuantities': [1],
 'TicketTypeNotes': '',
 'TicketClass': 0,
 'TicketClassName': None,
 'BuyUrl': '/secure/buy/Initialise?ListingID=5575812083&EventID=150339092&CategoryId=5973',
 'RowId': None,
 'TicketTypeId': 10,
 'RowContent': 'Row',
 'DisplayPrice': 32.0,
 'SellerTrackingKey': 'e205966f-497c-4d4f-b5f6-6be10d8e63ba'
  }
